# %% [markdown]
# # Module 3 - Data Manipulation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Delete Duplicate Data

# %%
#create duplicate data
names = ['Jessica','John','Bob','Jessica','Mary','John','Mel','Mel']
grades = [95,78,76,95,77,78,99,100]
GradeList = list(zip(names,grades))
df = pd.DataFrame(data = GradeList, columns=['Names', 'Grades'])
df
# Out:
#      Names  Grades
# 0  Jessica      95
# 1     John      78
# 2      Bob      76
# 3  Jessica      95
# 4     Mary      77
# 5     John      78
# 6      Mel      99
# 7      Mel     100

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True
# Out:
#      Names  Grades
# 3  Jessica      95
# 5     John      78

# %%
#drops duplicate rows, default is to keep first observation
nodupedf = df.drop_duplicates()
nodupedf.count()
# Out:
# Names     6
# Grades    6
# dtype: int64

# %%
#keep last observation
df.drop_duplicates(['Names'], keep='last')
# Out:
#      Names  Grades
# 2      Bob      76
# 3  Jessica      95
# 4     Mary      77
# 5     John      78
# 7      Mel     100

# %% [markdown]
# ### Select Rows by a Condition

# %%
#create fake data

names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,-2,77,78,101]

GradeList = list(zip(names,grades))

df = pd.DataFrame(data = GradeList, columns=['Names', 'Grades'])
df
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      -2
# 2     Mary      77
# 3     John      78
# 4      Mel     101

# %%
#find rows equal to 101
df.loc[df['Grades'] == 101]
# Out:
#   Names  Grades
# 4   Mel     101

# %%
#finds rows where the grade is less than or equal to 100
df.loc[df['Grades'] <= 100]
# Out:
#      Names  Grades
# 0      Bob      76
# 1  Jessica      -2
# 2     Mary      77
# 3     John      78

# %%
#multiple conditions
df.loc[(df['Grades'] >= 60) & (df['Grades'] < 100)] #between 60 and 100
# Out:
#   Names  Grades
# 0   Bob      76
# 2  Mary      77
# 3  John      78

# %%
#replacing values with new value
df.loc[df['Grades'] <= 77, 'Grades'] = 100
df
# Out:
#      Names  Grades
# 0      Bob     100
# 1  Jessica     100
# 2     Mary     100
# 3     John      78
# 4      Mel     101

# %% [markdown]
# ### Missing Data

# %%
df = pd.read_csv("datasets/gradedatamissing.csv")
df.head()
# Out:
#      fname     lname  gender   age  exercise  hours  grade  \
# 0   Marcia      Pugh  female  17.0       3.0   10.0   82.4
# 1   Kadeem  Morrison    male  18.0       4.0    4.0   78.2
# 2     Nash    Powell    male  18.0       5.0    9.0   79.3
# 3  Noelani    Wagner  female  14.0       2.0    7.0   83.2
# 4  Noelani    Cherry  female  18.0       4.0   15.0   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
#Selecting rows with no missing age or gender
df[df['age'].notnull() & df['gender'].notnull()]
# Out:
#           fname      lname  gender   age  exercise  hours  grade  \
# 0        Marcia       Pugh  female  17.0       3.0   10.0   82.4
# 1        Kadeem   Morrison    male  18.0       4.0    4.0   78.2
# 2          Nash     Powell    male  18.0       5.0    9.0   79.3
# 3       Noelani     Wagner  female  14.0       2.0    7.0   83.2
# 4       Noelani     Cherry  female  18.0       4.0   15.0   87.4
# 5          Neil    Whitley    male  16.0       5.0   16.0   88.7
# 6         Nelle     Golden  female  17.0       1.0    9.0   80.2
# 7       Armando    Hoffman    male  17.0       5.0   18.0   95.1
# 8       Illiana      Rojas  female  15.0       5.0    9.0   76.5
# 9        Victor   Richards    male  17.0       2.0    1.0   73.0
# 10         Neil     Wooten    male  15.0       3.0   15.0   89.7
# 11       Daquan    Alvarez    male  16.0       2.0   13.0   85.2
# 12         Nola  Velazquez  female  15.0       2.0   10.0   75.3
# 13        Quinn     Warren  female  14.0       4.0   12.0   80.7
# 14      Frances  Velasquez  female  15.0       2.0   15.0   84.2
# 15      Lareina      Poole  female  18.0       1.0   14.0   87.6
# 16        Medge   Mccarthy  female  15.0       1.0    8.0   75.8
# 17         Kibo      Gates    male  16.0       1.0   10.0   88.2
# 18        Libby     Guzman  female  19.0       1.0   19.0  100.0
# 19       Shelly    Rosario  female  18.0       4.0   13.0   84.3
# 20         Lane       Tate    male  19.0       4.0   11.0   84.2
# 21      Isadora       Case  female  18.0       3.0   11.0   79.1
# 22        Maggy  Whitfield  female  15.0       1.0   15.0   90.5
# 23        Elton     Wagner    male  16.0       2.0    9.0   71.0
# 24        Lance   Benjamin    male  14.0       5.0   18.0   90.3
# 25         Kyle    Skinner    male  17.0       5.0    6.0   82.4
# 26        Colin      Cohen    male  14.0       1.0   10.0   83.8
# 27      Solomon  Mcpherson    male  15.0       5.0   18.0   94.5
# 28         Ulla     Warren  female  18.0       1.0   16.0   83.5
# 29        Tyler    Collier    male  16.0       1.0    9.0   69.7
# ...         ...        ...     ...   ...       ...    ...    ...
# 1972    Armando    Mcclure    male  19.0       2.0   14.0   93.2
# 1973      Haley    Mcgowan  female  17.0       3.0   16.0   90.4
# 1974      Fritz      Rojas    male  17.0       5.0   13.0   79.5
# 1975  Allistair      Boyer    male  14.0       3.0   10.0   74.2
# 1976       Ella  Patterson  female  16.0       1.0    8.0   68.0
# 1977      Felix    Freeman    male  15.0       4.0   11.0   75.2
# 1978       Dean      Oneil    male  16.0       2.0    8.0   74.5
# 1979    Quinlan    Hawkins    male  14.0       3.0   18.0   85.6
# 1980      Kiara       Lott  female  17.0       2.0   12.0   82.7
# 1981        Kai    Woodard  female  17.0       5.0   17.0  100.0
# 1982     Maxine    Raymond  female  17.0       4.0   19.0   91.9
# 1983       Leah   Lawrence  female  15.0       5.0   15.0  100.0
# 1984      Kalia      Lewis  female  18.0       1.0    6.0   61.4
# 1985    Anthony     Palmer    male  14.0       1.0   14.0   93.1
# 1986     Joshua   Randolph    male  15.0       1.0    4.0   72.7
# 1987      Akeem       Luna    male  15.0       4.0    6.0   74.4
# 1988     Indigo      Mccoy  female  19.0       2.0   14.0   91.3
# 1989      Price       Wall    male  15.0       5.0   11.0   78.6
# 1990      Quinn  Patterson    male  15.0       1.0   14.0   78.0
# 1991       John       Ford    male  14.0       2.0   14.0   91.2
# 1992      Adena     Battle  female  17.0       2.0    8.0   70.2
# 1993      Craig     Obrien    male  16.0       3.0    7.0   64.9
# 1994   Isabelle     Barber  female  14.0       5.0    9.0   78.5
# 1995       Risa     Watson  female  14.0       2.0   10.0   74.3
955 Glen Ridge Rd., Plattsburgh, NY 12901
# 1995     37 Augusta Lane, Montgomery Village, MD 20886
# 1996       75 Wild Horse Street, Panama City, FL 32404
# 1997             982 West Street, Alexandria, VA 22304
# 1998        78 Morris Street, East Northport, NY 11731
# 1999             30 Glenridge Rd., Bountiful, UT 84010
# 2000       342 West Meadowbrook Lane, Helena, MT 59601
# 2001            81 Homestead Drive, Voorhees, NJ 08043
#
# [1993 rows x 8 columns]

# %%
#drop rows with any missing data
df_no_missing = df.dropna()
df_no_missing
# Out:
#           fname      lname  gender   age  exercise  hours  grade  \
# 0        Marcia       Pugh  female  17.0       3.0   10.0   82.4
# 1        Kadeem   Morrison    male  18.0       4.0    4.0   78.2
# 2          Nash     Powell    male  18.0       5.0    9.0   79.3
# 3       Noelani     Wagner  female  14.0       2.0    7.0   83.2
# 4       Noelani     Cherry  female  18.0       4.0   15.0   87.4
# 5          Neil    Whitley    male  16.0       5.0   16.0   88.7
# 6         Nelle     Golden  female  17.0       1.0    9.0   80.2
# 7       Armando    Hoffman    male  17.0       5.0   18.0   95.1
# 8       Illiana      Rojas  female  15.0       5.0    9.0   76.5
# 9        Victor   Richards    male  17.0       2.0    1.0   73.0
# 10         Neil     Wooten    male  15.0       3.0   15.0   89.7
# 11       Daquan    Alvarez    male  16.0       2.0   13.0   85.2
# 12         Nola  Velazquez  female  15.0       2.0   10.0   75.3
# 13        Quinn     Warren  female  14.0       4.0   12.0   80.7
# 14      Frances  Velasquez  female  15.0       2.0   15.0   84.2
# 15      Lareina      Poole  female  18.0       1.0   14.0   87.6
# 16        Medge   Mccarthy  female  15.0       1.0    8.0   75.8
# 17         Kibo      Gates    male  16.0       1.0   10.0   88.2
# 18        Libby     Guzman  female  19.0       1.0   19.0  100.0
# 19       Shelly    Rosario  female  18.0       4.0   13.0   84.3
# 20         Lane       Tate    male  19.0       4.0   11.0   84.2
# 21      Isadora       Case  female  18.0       3.0   11.0   79.1
# 22        Maggy  Whitfield  female  15.0       1.0   15.0   90.5
# 23        Elton     Wagner    male  16.0       2.0    9.0   71.0
# 24        Lance   Benjamin    male  14.0       5.0   18.0   90.3
# 25         Kyle    Skinner    male  17.0       5.0    6.0   82.4
# 26        Colin      Cohen    male  14.0       1.0   10.0   83.8
# 27      Solomon  Mcpherson    male  15.0       5.0   18.0   94.5
# 28         Ulla     Warren  female  18.0       1.0   16.0   83.5
# 29        Tyler    Collier    male  16.0       1.0    9.0   69.7
# ...         ...        ...     ...   ...       ...    ...    ...
# 1972    Armando    Mcclure    male  19.0       2.0   14.0   93.2
# 1973      Haley    Mcgowan  female  17.0       3.0   16.0   90.4
# 1974      Fritz      Rojas    male  17.0       5.0   13.0   79.5
# 1975  Allistair      Boyer    male  14.0       3.0   10.0   74.2
# 1976       Ella  Patterson  female  16.0       1.0    8.0   68.0
# 1977      Felix    Freeman    male  15.0       4.0   11.0   75.2
# 1978       Dean      Oneil    male  16.0       2.0    8.0   74.5
# 1979    Quinlan    Hawkins    male  14.0       3.0   18.0   85.6
# 1980      Kiara       Lott  female  17.0       2.0   12.0   82.7
# 1981        Kai    Woodard  female  17.0       5.0   17.0  100.0
# 1982     Maxine    Raymond  female  17.0       4.0   19.0   91.9
914 NW. Lawrence Street, Lawrenceville, GA 30043
# 1986       9632 NE. Lakeshore St., Riverside, NJ 08075
# 1987              750 Adams Drive, Goldsboro, NC 27530
# 1988         9652 Columbia Ave., Chattanooga, TN 37421
# 1989           8672 S. 53rd Drive, Waterford, MI 48329
# 1990           634 Cedar Swamp Ave., Burbank, IL 60459
# 1991       64 Devonshire Street, Orange Park, FL 32065
# 1992       9272 Elizabeth Drive, Londonderry, NH 03053
# 1993                524 Park Ave., Hollywood, FL 33020
# 1994         955 Glen Ridge Rd., Plattsburgh, NY 12901
# 1995     37 Augusta Lane, Montgomery Village, MD 20886
# 1996       75 Wild Horse Street, Panama City, FL 32404
# 1997             982 West Street, Alexandria, VA 22304
# 1998        78 Morris Street, East Northport, NY 11731
# 1999             30 Glenridge Rd., Bountiful, UT 84010
# 2000       342 West Meadowbrook Lane, Helena, MT 59601
# 2001            81 Homestead Drive, Voorhees, NJ 08043
#
# [1984 rows x 8 columns]

# %%
#replace empty cells with 0
df.fillna(0)
# Out:
#           fname      lname  gender   age  exercise  hours  grade  \
# 0        Marcia       Pugh  female  17.0       3.0   10.0   82.4
# 1        Kadeem   Morrison    male  18.0       4.0    4.0   78.2
# 2          Nash     Powell    male  18.0       5.0    9.0   79.3
# 3       Noelani     Wagner  female  14.0       2.0    7.0   83.2
# 4       Noelani     Cherry  female  18.0       4.0   15.0   87.4
# 5          Neil    Whitley    male  16.0       5.0   16.0   88.7
# 6         Nelle     Golden  female  17.0       1.0    9.0   80.2
# 7       Armando    Hoffman    male  17.0       5.0   18.0   95.1
# 8       Illiana      Rojas  female  15.0       5.0    9.0   76.5
# 9        Victor   Richards    male  17.0       2.0    1.0   73.0
# 10         Neil     Wooten    male  15.0       3.0   15.0   89.7
# 11       Daquan    Alvarez    male  16.0       2.0   13.0   85.2
# 12         Nola  Velazquez  female  15.0       2.0   10.0   75.3
# 13        Quinn     Warren  female  14.0       4.0   12.0   80.7
# 14      Frances  Velasquez  female  15.0       2.0   15.0   84.2
# 15      Lareina      Poole  female  18.0       1.0   14.0   87.6
# 16        Medge   Mccarthy  female  15.0       1.0    8.0   75.8
# 17         Kibo      Gates    male  16.0       1.0   10.0   88.2
# 18        Libby     Guzman  female  19.0       1.0   19.0  100.0
# 19       Shelly    Rosario  female  18.0       4.0   13.0   84.3
# 20         Lane       Tate    male  19.0       4.0   11.0   84.2
# 21      Isadora       Case  female  18.0       3.0   11.0   79.1
# 22        Maggy  Whitfield  female  15.0       1.0   15.0   90.5
# 23        Elton     Wagner    male  16.0       2.0    9.0   71.0
# 24        Lance   Benjamin    male  14.0       5.0   18.0   90.3
# 25         Kyle    Skinner    male  17.0       5.0    6.0   82.4
# 26        Colin      Cohen    male  14.0       1.0   10.0   83.8
# 27      Solomon  Mcpherson    male  15.0       5.0   18.0   94.5
# 28         Ulla     Warren  female  18.0       1.0   16.0   83.5
# 29        Tyler    Collier    male  16.0       1.0    9.0   69.7
# 26            23 Lakewood Street, Lake Worth, FL 33460
# 27     7465 North Pearl St., Massapequa Park, NY 11762
# 28               89 Fairview Avenue, Hopkins, MN 55343
# 29             65 Lookout Street, Marshfield, WI 54449
# ...                                                ...
# 1972                23 Hall Road, Hagerstown, MD 21740
# 1973        4 Wellington Street, Saint Louis, MO 63109
# 1974         16 East Edgewood St., Ashtabula, OH 44004
# 1975                9373 Helen Drive, Leland, NC 28451
# 1976              999 Nicolls Avenue, Oviedo, FL 32765
# 1977             671 Division Ave., Vineland, NJ 08360
# 1978        653 East Saxton Lane, Framingham, MA 01701
# 1979       9437 Longbranch Street, Rockville, MD 20850
# 1980           7110 Ridge Road, Jacksonville, NC 28540
# 1981              37 Addison St., Eastpointe, MI 48021
# 1982               739 Thomas Court, Memphis, TN 38106
# 1983           652 Pine Drive, Mountain View, CA 94043
# 1984    557 Theatre Lane, Green Cove Springs, FL 32043
# 1985  914 NW. Lawrence Street, Lawrenceville, GA 30043
# 1986       9632 NE. Lakeshore St., Riverside, NJ 08075
# 1987              750 Adams Drive, Goldsboro, NC 27530
# 1988         9652 Columbia Ave., Chattanooga, TN 37421
# 1989           8672 S. 53rd Drive, Waterford, MI 48329
# 1990           634 Cedar Swamp Ave., Burbank, IL 60459
# 1991       64 Devonshire Street, Orange Park, FL 32065
# 1992       9272 Elizabeth Drive, Londonderry, NH 03053
# 1993                524 Park Ave., Hollywood, FL 33020
# 1994         955 Glen Ridge Rd., Plattsburgh, NY 12901
# 1995     37 Augusta Lane, Montgomery Village, MD 20886
# 1996       75 Wild Horse Street, Panama City, FL 32404
# 1997             982 West Street, Alexandria, VA 22304
# 1998        78 Morris Street, East Northport, NY 11731
# 1999             30 Glenridge Rd., Bountiful, UT 84010
# 2000       342 West Meadowbrook Lane, Helena, MT 59601
# 2001            81 Homestead Drive, Voorhees, NJ 08043
#
# [2002 rows x 8 columns]

# %%
#replace empty cells with average of column
df["grade"].fillna(df["grade"].mean(), inplace=True)

# %% [markdown]
# ### Binning Data

# %%
filename = "datasets/gradedata.csv"
df = pd.read_csv(filename)

df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df['grade'].dtypes
# Out:
# dtype('float64')

# %%
#Define bins as 0-59, 60-69, 70-79, 80-89, 90-100
bins = [0, 60, 70, 80, 90, 100]

# Create names for the four groups
group_names = ['F', 'D', 'C', 'B', 'A']

#make new column with letter grades
df['lettergrade'] = pd.cut(df['grade'], bins, labels=group_names)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address lettergrade
# 0   9253 Richardson Road, Matawan, NJ 07747           B
# 1          33 Spring Dr., Taunton, MA 02780           C
# 2          41 Hill Avenue, Mentor, OH 44060           C
# 3        8839 Marshall St., Miami, FL 33125           B
# 4  8304 Charles Rd., Lewis Center, OH 43035           B

# %%
pd.value_counts(df['lettergrade']) # number of observations per letter grade
# Out:
# B    737
# C    580
# A    475
# D    193
# F     15
# Name: lettergrade, dtype: int64

# %%
df.groupby('lettergrade')['hours'].mean() #mean of hours studied per letter grade
# Out:
# lettergrade
# F     3.933333
# D     5.544041
# C     8.381034
# B    11.827680
# A    15.305263
# Name: hours, dtype: float64

# %%
#apply functions to data
df['grade'] = df['grade'].apply(lambda x: int(x)) #turns float type grades to int type
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10     82
# 1   Kadeem  Morrison    male   18         4      4     78
# 2     Nash    Powell    male   18         5      9     79
# 3  Noelani    Wagner  female   14         2      7     83
# 4  Noelani    Cherry  female   18         4     15     87
#
#                                     address lettergrade
# 0   9253 Richardson Road, Matawan, NJ 07747           B
# 1          33 Spring Dr., Taunton, MA 02780           C
# 2          41 Hill Avenue, Mentor, OH 44060           C
# 3        8839 Marshall St., Miami, FL 33125           B
# 4  8304 Charles Rd., Lewis Center, OH 43035           B

# %% [markdown]
# ### Add and Remove Columns

# %%
names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,95,77,78,99]
bsdegress = [1,1,0,0,1]
msdegrees = [2,1,0,0,0]
phddegrees = [0,1,0,0,0]

GradeList = list(zip(names,grades,bsdegress,msdegrees,phddegrees))

df = pd.DataFrame(data = GradeList, columns=['Names','Grades','BS','MS','PhD'])
df
# Out:
#      Names  Grades  BS  MS  PhD
# 0      Bob      76   1   2    0
# 1  Jessica      95   1   1    1
# 2     Mary      77   0   0    0
# 3     John      78   0   0    0
# 4      Mel      99   1   0    0

# %%
#make a new column with each value = 0
df['HighSchool']=0

#make new column with all NaN values
df['Preschool'] = np.nan

#manually add data for new column
d = ([0,1,0,1,0])
s = pd.Series(d, index= df.index)
df['DriversLicense'] = s

df
# Out:
#      Names  Grades  BS  MS  PhD  HighSchool  Preschool  DriversLicense
# 0      Bob      76   1   2    0           0        NaN               0
# 1  Jessica      95   1   1    1           0        NaN               1
# 2     Mary      77   0   0    0           0        NaN               0
# 3     John      78   0   0    0           0        NaN               1
# 4      Mel      99   1   0    0           0        NaN               0

# %%
df.loc[df['Names'] == 'Mel']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Names'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-c768c7e209c8> in <module>
# ----> 1 df.loc[df['Names'] == 'Mel']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Names'

# %%
#drop a column
df.drop('PhD', axis=1)
# Out:
#      Names  Grades  BS  MS  HighSchool  Preschool  DriversLicense
# 0      Bob      76   1   2           0        NaN               0
# 1  Jessica      95   1   1           0        NaN               1
# 2     Mary      77   0   0           0        NaN               0
# 3     John      78   0   0           0        NaN               1
# 4      Mel      99   1   0           0        NaN               0

# %%
#drop completely empty columns (all NaN/null values)
df.dropna(axis=1, how='all')
# Out:
#      Names  Grades  BS  MS  PhD  HighSchool  DriversLicense
# 0      Bob      76   1   2    0           0               0
# 1  Jessica      95   1   1    1           0               1
# 2     Mary      77   0   0    0           0               0
# 3     John      78   0   0    0           0               1
# 4      Mel      99   1   0    0           0               0

# %% [markdown]
# #### Make new columns

# %%
#using functions
filename = "datasets/gradedata.csv"
df = pd.read_csv(filename)

def singlename(fn, ln):
    return fn + " " + ln

df['fullname'] = singlename(df['fname'], df['lname'])
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address         fullname
# 0   9253 Richardson Road, Matawan, NJ 07747      Marcia Pugh
# 1          33 Spring Dr., Taunton, MA 02780  Kadeem Morrison
# 2          41 Hill Avenue, Mentor, OH 44060      Nash Powell
# 3        8839 Marshall St., Miami, FL 33125   Noelani Wagner
# 4  8304 Charles Rd., Lewis Center, OH 43035   Noelani Cherry

# %%
#create column based on binary conditional
df['isFailing'] = np.where(df['grade']<70, 'yes', 'no')
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address            fullname  \
# 1995        982 West Street, Alexandria, VA 22304       Cody Shepherd
# 1996   78 Morris Street, East Northport, NY 11731  Geraldine Peterson
# 1997        30 Glenridge Rd., Bountiful, UT 84010       Mercedes Leon
# 1998  342 West Meadowbrook Lane, Helena, MT 59601      Lucius Rowland
# 1999       81 Homestead Drive, Voorhees, NJ 08043        Linus Morris
#
#      isFailing
# 1995        no
# 1996        no
# 1997        no
# 1998       yes
# 1999        no

# %%
#make numeric value column based on string value column

#create a function that will return 1 if female and 0 if male
def score_to_numeric(x):
    if x=='female':
        return 1
    if x=='male':
        return 0
    
df['gender_val'] = df['gender'].apply(score_to_numeric)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address            fullname  \
# 1995        982 West Street, Alexandria, VA 22304       Cody Shepherd
# 1996   78 Morris Street, East Northport, NY 11731  Geraldine Peterson
# 1997        30 Glenridge Rd., Bountiful, UT 84010       Mercedes Leon
# 1998  342 West Meadowbrook Lane, Helena, MT 59601      Lucius Rowland
# 1999       81 Homestead Drive, Voorhees, NJ 08043        Linus Morris
#
#      isFailing  gender_val
# 1995        no           0
# 1996        no           1
# 1997        no           1
# 1998       yes           0
# 1999        no           0

# %% [markdown]
# ### Sort Values

# %%
#still using gradedata.csv
#df.head() if needed

df.sort_values('hours') #default is ascending=True
#does not change structure of df
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 1611    Garrett    Everett    male   17         2      0   78.1
# 1213     Arthur     Nieves    male   14         3      0   76.8
# 356        Luke    Santana    male   17         1      0   75.0
# 80         Hoyt      Lyons    male   16         5      1   71.3
# 1507     Ferris      Avila    male   18         5      1   74.2
# 1931       Luke   Morrison    male   19         5      2   70.1
# 1317     Kessie   Mcdonald  female   17         1      2   62.2
# 1359        Jin     Valdez    male   19         2      2   77.0
# 1110     Xerxes     Mooney  female   17         1      2   70.4
# 903         Lee     Barber    male   15         2      2   62.3
# 1916      Kevin   Townsend    male   14         5      2   60.1
# 836        Abel   Stephens    male   18         4      2   68.2
# 1640      Nolan      Small    male   14         3      2   71.5
# 700      Steven    Sherman    male   18         1      2   60.0
# 410       Linda    Baldwin  female   16         5      2   59.0
# 393     Gabriel     Jordan    male   16         4      2   62.0
# 1758       Omar    Pittman    male   14         5      2   66.6
# 556       Lacey     Nieves  female   18         1      2   57.9
# 1449    Gillian     Norris  female   19         5      2   63.4
# 1278    Barclay    Nichols    male   19         0      2   66.3
# 1407     Hamish      Simon    male   18         4      3   71.2
# 645      Stella     Taylor  female   19         3      3   65.5
# 44        Dolan       Ford    male   14         3      3   64.2
# 672      Ciaran        Gay    male   19         4      3   59.3
# 1586      Burke    Bennett    male   17         1      3   65.8
# 48      Aurelia    Clayton  female   14         5      3   72.1
# 951    Marshall     Sexton    male   18         1      3   62.6
# 68       Isaiah    Patrick    male   19         4      3   65.3
# 825               273 Anderson Lane, Perkasie, PA 18944        Kevin Smith
#
#      isFailing  gender_val
# 1611        no           0
# 1213        no           0
# 356         no           0
# 80          no           0
# 1507        no           0
# 1931        no           0
# 1317       yes           1
# 1359        no           0
# 1110        no           1
# 903        yes           0
# 1916       yes           0
# 836        yes           0
# 1640        no           0
# 700        yes           0
# 410        yes           1
# 393        yes           0
# 1758       yes           0
# 556        yes           1
# 1449       yes           1
# 1278       yes           0
# 1407        no           0
# 645        yes           1
# 44         yes           0
# 672        yes           0
# 1586       yes           0
# 48          no           1
# 951        yes           0
# 68         yes           0
# 302        yes           1
# 760         no           1
# ...        ...         ...
# 610         no           1
# 1853        no           0
# 1834        no           0
# 1980        no           1
# 584         no           1
# 270         no           0
# 1184        no           1
# 89          no           0
# 252         no           1
# 1070        no           0
# 36          no           0
# 164         no           0
# 1356        no           0
# 508         no           1
# 1733        no           1
# 1719        no           1
# 1144        no           1
# 204         no           0
# 101         no           1
# 616         no           0
# 1481        no           1
# 1889        no           0
# 226         no           0
# 1665        no           0
# 1021        no           1
# 690         no           0
# 954         no           1
# 1650        no           1
# 32          no           1
# 825         no           0
#
# [2000 rows x 11 columns]

# %% [markdown]
# ### Calculate and Remove Outliers

# %%
#still using gradedata.csv
#check df.head() if needed

#Standard Deviation Method

meangrade = df['grade'].mean()
stdgrade = df['grade'].std()
toprange = meangrade + stdgrade * 1.96
botrange = meangrade - stdgrade * 1.96

newdf = df.copy() #to not mess up the original df
newdf = newdf.drop(newdf[newdf['grade'] > toprange].index)
newdf = newdf.drop(newdf[newdf['grade'] < botrange].index)

newdf.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address         fullname isFailing  \
# 0   9253 Richardson Road, Matawan, NJ 07747      Marcia Pugh        no
# 1          33 Spring Dr., Taunton, MA 02780  Kadeem Morrison        no
# 2          41 Hill Avenue, Mentor, OH 44060      Nash Powell        no
# 3        8839 Marshall St., Miami, FL 33125   Noelani Wagner        no
# 4  8304 Charles Rd., Lewis Center, OH 43035   Noelani Cherry        no
#
#    gender_val
# 0           1
# 1           0
# 2           0
# 3           1
# 4           1

# %%
#Interquartile Range Method

q1 = df['grade'].quantile(.25)
q3 = df['grade'].quantile(.75)
iqr = q3-q1
toprange = q3 + iqr * 1.5
botrange = q1 - iqr * 1.5

newdf = df.copy()
newdf = newdf.drop(newdf[newdf['grade'] > toprange].index)
newdf = newdf.drop(newdf[newdf['grade'] < botrange].index)

newdf.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address         fullname isFailing  \
# 0   9253 Richardson Road, Matawan, NJ 07747      Marcia Pugh        no
# 1          33 Spring Dr., Taunton, MA 02780  Kadeem Morrison        no
# 2          41 Hill Avenue, Mentor, OH 44060      Nash Powell        no
# 3        8839 Marshall St., Miami, FL 33125   Noelani Wagner        no
# 4  8304 Charles Rd., Lewis Center, OH 43035   Noelani Cherry        no
#
#    gender_val
# 0           1
# 1           0
# 2           0
# 3           1
# 4           1

# %%
df.loc[df['Names'] == 'Mel']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Names'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-c768c7e209c8> in <module>
# ----> 1 df.loc[df['Names'] == 'Mel']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Names'
