# %%
import pandas as pd
import numpy as np

ShinyDiamonds_df = pd.read_csv('diamonds.csv')

# %%
ShinyDiamonds_df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
ShinyDiamonds_df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
ShinyDiamonds_df.columns = ['Item', 'Carat', 'Cut', 'Color', 'Clarity', 'Depth', 'Table', 'Price', 'Length', 'Width', 'Depth']
ShinyDiamonds_df.head()
# Out:
#    Item  Carat      Cut Color Clarity  Depth  Table  Price  Length  Width  \
# 0     1   0.23    Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1     2   0.21  Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2     3   0.23     Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3     4   0.29  Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4     5   0.31     Good     J     SI2   63.3   58.0    335    4.34   4.35
#
#    Depth
# 0   2.43
# 1   2.31
# 2   2.31
# 3   2.63
# 4   2.75

# %%
ShinyDiamonds_df.sort_values('Color')
# Out:
#         Item  Carat        Cut Color Clarity  Depth  Table  Price  Length  \
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757    5.83
# 7817    7818   1.00  Very Good     D     SI2   63.5   59.0   4295    6.35
# 7816    7817   1.00       Good     D     SI2   57.8   58.0   4295    6.61
# 7815    7816   1.00  Very Good     D     SI2   61.5   63.0   4295    6.32
# 7809    7810   0.56      Ideal     D      IF   61.9   57.0   4293    5.28
# 7804    7805   0.90  Very Good     D     SI1   61.8   59.0   4291    6.13
# 7793    7794   0.90  Very Good     D     SI1   62.1   60.0   4289    6.11
# 7791    7792   0.71       Good     D     VS2   63.6   54.0   4289    5.70
# 35459  35460   0.43    Premium     D     VS2   59.7   59.0    901    4.89
# 7769    7770   0.81    Premium     D     VS1   62.3   58.0   4284    5.94
# 35527  35528   0.30      Ideal     D    VVS1   61.9   57.0    905    4.27
# 7753    7754   0.64      Ideal     D    VVS1   61.5   56.0   4281    5.57
# ...

# %%
ShinyDiamonds_df['Color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: Color, dtype: int64

# %%
df2 = ShinyDiamonds_df.copy()

# %%
dfg = df2.loc[df2['Color'] == 'G'] 
dfg
# Out:
#         Item  Carat        Cut Color Clarity  Depth  Table  Price  Length  \
# 25        26   0.23  Very Good     G    VVS2   60.4   58.0    354    3.97
# 51        52   0.23      Ideal     G     VS1   61.9   54.0    404    3.93
# 65        66   0.28      Ideal     G    VVS2   61.4   56.0    553    4.19
# 67        68   0.31  Very Good     G     SI1   63.3   57.0    553    4.33
# 68        69   0.31    Premium     G     SI1   61.8   58.0    553    4.35
# 85        86   0.24    Premium     G    VVS1   62.3   59.0    554    3.95
# 92        93   0.70      Ideal     G     VS2   61.6   56.0   2757    5.70
# 94        95   0.78  Very Good     G     SI2   63.8   56.0   2759    5.81
# 102      103   0.74      Ideal     G     SI1   61.6   55.0   2760    5.80
# 103      104   0.75    Premium     G     VS2   61.7   58.0   2760    5.85
# 105      106   0.75      Ideal     G     SI1   62.2   55.0   2760    5.87
# 106      107   0.80    Premium     G     SI1   63.0   59.0   2760    5.90
# ...

# %%
dfg.describe()
# Out:
#                Item         Carat         Depth         Table         Price  \
# count  11292.000000  11292.000000  11292.000000  11292.000000  11292.000000
# mean   27725.462983      0.771190     61.757111     57.288629   3999.135671
# std    14916.600917      0.441436      1.370010      2.147330   4051.102846
# min       26.000000      0.230000     43.000000     52.000000    354.000000
# 25%    15996.750000      0.390000     61.100000     56.000000    931.000000
# 50%    27835.000000      0.700000     61.800000     57.000000   2242.000000
# 75%    40157.250000      1.040000     62.500000     59.000000   6048.000000
# max    53930.000000      3.010000     72.900000     76.000000  18818.000000
#
#              Length         Width         Depth
# count  11292.000000  11292.000000  11292.000000
# mean       5.677543      5.680192      3.505021
# std        1.083102      1.075058      0.674413
# min        0.000000      0.000000      0.000000
# ...

# %%
dfg = dfg.loc[dfg['Price'] == 354] 
dfg
# Out:
#     Item  Carat        Cut Color Clarity  Depth  Table  Price  Length  Width  \
# 25    26   0.23  Very Good     G    VVS2   60.4   58.0    354    3.97   4.01
#
#     Depth
# 25   2.41
